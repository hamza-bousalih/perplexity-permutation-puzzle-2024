# %%
import gc
import os
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch

from collections import deque
from typing import Tuple, List
from collections import deque
import random

# %%
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class ParticipantVisibleError(Exception):
    pass

def score(
    solution: pd.DataFrame,
    submission: pd.DataFrame,
    row_id_column_name: str,
    model_path: str = '/kaggle/input/gemma-2/transformers/gemma-2-9b/2',
    load_in_8bit: bool = False,
    clear_mem: bool = False,
) -> float:
    # Check that each submitted string is a permutation of the solution string
    sol_counts = solution.loc[:, 'text'].str.split().apply(Counter)
    sub_counts = submission.loc[:, 'text'].str.split().apply(Counter)
    invalid_mask = sol_counts != sub_counts
    if invalid_mask.any():
        raise ParticipantVisibleError(
            'At least one submitted string is not a valid permutation of the solution string.'
        )

    # Calculate perplexity for the submitted strings
    sub_strings = [
        ' '.join(s.split()) for s in submission['text'].tolist()
    ]  # Split and rejoin to normalize whitespace
    scorer = PerplexityCalculator(
        model_path=model_path,
        load_in_8bit=load_in_8bit,
    )  # Initialize the perplexity calculator with a pre-trained model
    perplexities = scorer.get_perplexity(
        sub_strings
    )  # Calculate perplexity for each submitted string

    if clear_mem:
        # Just move on if it fails. Not essential if we have the score.
        try:
            scorer.clear_gpu_memory()
        except:
            print('GPU memory clearing failed.')

    return float(np.mean(perplexities))

class PerplexityCalculator:
    def __init__(
        self,
        model_path: str,
        load_in_8bit: bool = False,
        device_map: str = 'auto',
    ):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)
        # Configure model loading based on quantization setting and device availability
        if load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires CUDA device')
            quantization_config = transformers.BitsAndBytesConfig(load_in_8bit=True)
            self.model = transformers.AutoModelForCausalLM.from_pretrained(
                model_path,
                quantization_config=quantization_config,
                device_map=device_map,
            )
        else:
            self.model = transformers.AutoModelForCausalLM.from_pretrained(
                model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=device_map,
            )

        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

        self.model.eval()

    def get_perplexity(
        self, input_texts: Union[str, List[str]], debug=False
    ) -> Union[float, List[float]]:
        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        with torch.no_grad():
            # Process each sequence independently
            for text in input_texts:
                # Explicitly add sequence boundary tokens to the text
                text_with_special = f"{self.tokenizer.bos_token}{text}{self.tokenizer.eos_token}"

                # Tokenize
                model_inputs = self.tokenizer(
                    text_with_special,
                    return_tensors='pt',
                    add_special_tokens=False,
                )

                if 'token_type_ids' in model_inputs:
                    model_inputs.pop('token_type_ids')

                model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                # Get model output
                output = self.model(**model_inputs, use_cache=False)
                logits = output['logits']

                # Shift logits and labels for calculating loss
                shift_logits = logits[..., :-1, :].contiguous()  # Drop last prediction
                shift_labels = model_inputs['input_ids'][..., 1:].contiguous()  # Drop first input

                # Calculate token-wise loss
                loss = self.loss_fct(
                    shift_logits.view(-1, shift_logits.size(-1)),
                    shift_labels.view(-1)
                )

                # Calculate average loss
                sequence_loss = loss.sum() / len(loss)
                loss_list.append(sequence_loss.cpu().item())

                # Debug output
                if debug:
                    print(f"\nProcessing: '{text}'")
                    print(f"With special tokens: '{text_with_special}'")
                    print(f"Input tokens: {model_inputs['input_ids'][0].tolist()}")
                    print(f"Target tokens: {shift_labels[0].tolist()}")
                    print(f"Input decoded: {self.tokenizer.decode(model_inputs['input_ids'][0])}")
                    print(f"Target decoded: {self.tokenizer.decode(shift_labels[0])}")
                    print(f"Individual losses: {loss.tolist()}")
                    print(f"Average loss: {sequence_loss.item():.4f}")

        ppl = [exp(i) for i in loss_list]

        if debug:
            print("\nFinal perplexities:")
            for text, perp in zip(input_texts, ppl):
                print(f"Text: '{text}'")
                print(f"Perplexity: {perp:.2f}")

        return ppl[0] if single_input else ppl

    def clear_gpu_memory(self) -> None:
        if not torch.cuda.is_available():
            return

        # Delete model and tokenizer if they exist
        if hasattr(self, 'model'):
            del self.model
        if hasattr(self, 'tokenizer'):
            del self.tokenizer

        # Run garbage collection
        gc.collect()

        # Clear CUDA cache and reset memory stats
        with DEVICE:
            torch.cuda.empty_cache()
            torch.cuda.ipc_collect()
            torch.cuda.reset_peak_memory_stats()

# %%
model_path = "/kaggle/input/gemma-2/transformers/gemma-2-9b/2"
scorer = PerplexityCalculator(model_path=model_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ---
# # TabuSearch

# %%
class TabuSearch:
    def __init__(self, words: list, calculate_perplexity, tabu_tenure=5,
                 stop_on_non_improvement=20, max_iter=100, 
                 max_condidates=100,
                 debug=False, logger = None):
        self.words = words
        self.n = len(self.words)
        self.tabu_tenure = tabu_tenure
        self.stop_on_non_improvement = stop_on_non_improvement
        self.max_iter = max_iter
        self.calculate_perplexity = calculate_perplexity
        self.tabu_list = deque(maxlen=self.tabu_tenure)
        self.max_condidates = max_condidates
        self.debug = debug
        self.logger = logger

    def log(self, msg):
        if self.debug:
            if self.logger is None:
                print(f"[LOCAL SEARCH] {msg}")
            else:
                self.logger(f"[LOCAL SEARCH] {msg}")
    
    def is_move_used(self, move: Tuple[int, int]):
        return move in self.tabu_list
    
    def __to_sentence_text(self, sentence):
        return " ".join([self.words[i] for i in sentence])
    
    def to_tabulist(self, move):
        self.tabu_list.append(tuple(move))

    def get_candidates(self, solution: np.ndarray) -> List[Tuple[list, Tuple[int, int]]]:
        candidates = []

        itr = 0
        while itr < self.max_condidates:
            i,j = random.choices(solution, k=2)
            candidate = solution.copy()
            candidate[i], candidate[j] = candidate[j], candidate[i]
            candidates.append((candidate, (i, j)))
            itr+=1
        
        return candidates

    def optimize(self, current_sentence: np.ndarray) -> Tuple[np.ndarray, float]:
        self.log(f"start {current_sentence}")
        current_perplexity = self.calculate_perplexity(current_sentence)
        
        best_sentence = current_sentence
        best_perplexity = current_perplexity
        
        no_improvement = 0
        itr = 1
        
        while no_improvement < self.stop_on_non_improvement and itr <= self.max_iter:
            self.log(f"[ITER] [{itr}] --- {best_perplexity}")
            
            candidates = self.get_candidates(current_sentence)
            
            best_candidate = None
            best_candidate_perplexity = None
            used_move = None
            
            for candidate, swap in candidates:
                candidate_perplexity = self.calculate_perplexity(candidate)

                if best_candidate_perplexity is None \
                    or ((not self.is_move_used(swap)) or (candidate_perplexity < best_perplexity)) \
                        and (candidate_perplexity < best_candidate_perplexity):
                        best_candidate = candidate
                        best_candidate_perplexity = candidate_perplexity
                        used_move = swap
            
            self.log(f"[{best_candidate_perplexity}] {best_candidate}")
            
            if best_candidate_perplexity < best_perplexity:
                best_sentence = best_candidate
                best_perplexity = best_candidate_perplexity
                no_improvement = 0
                self.log(f"[IM] [{itr}/{self.max_iter}] [{best_perplexity}]")
            else:
                no_improvement += 1
                self.log(f"[NO IM] __{no_improvement}__")
            
            current_sentence = best_candidate
            current_perplexity = best_candidate_perplexity
            
            self.to_tabulist(used_move)
            itr+=1

            if(no_improvement == self.stop_on_non_improvement):
                self.log(f"[NO IM] break; {best_sentence} | {best_perplexity}")
            
        return best_sentence, best_perplexity

# %%
# import numpy as np

# words = problem['text'][0].split()
# print(words)

# init = np.random.permutation(len(words)).tolist()
# print(init)

# def __calculate_fitness(solution) -> float:
#     sentence = " ".join([words[i] for i in solution])
#     problem = pd.DataFrame({'id': [0], 'text': [sentence] })
#     perplexities = scorer.get_perplexity(problem["text"].tolist())
#     # print(f"{perplexities[0]} || {sentence}")
#     return perplexities[0]

# tabuSearch = TabuSearch(words, __calculate_fitness, tabu_tenure=10, stop_on_non_improvement=50, debug=True)

# tabuSearch.optimize(init)

# %% [markdown]
# ---

# %%
import numpy as np
from itertools import permutations

class WhaleOptimization:
    def __init__(self, sentence: str, scorer,
                 n_whales: int = 20, max_iter: int = 80,
                 tabu_tenure=10, tabu_no_imp=10, tabu_max_iter=50,
                 logger=None, debug=False):
        self.words = sentence.split(' ')
        self.n = len(self.words)
        self.scorer = scorer
        self.n_whales = n_whales
        self.max_iter = max_iter
        self.logger = logger
        self.debug = debug
        self.cur_whale = None
        self.itr = None
        self.TabuSearch = TabuSearch(
            self.words, 
            self.__calculate_fitness,
            tabu_tenure=tabu_tenure,
            stop_on_non_improvement=tabu_no_imp,
            max_iter=tabu_max_iter,
            debug=debug,
            logger=self.log
        )

        self.cache = {}
        self.calccached = 0
        self.calcnotcached = 0
        self.calcattempt = 0
    
    def __create_initial_sols(self) -> np.ndarray:
        """Create a random permutation solution"""
        return np.random.permutation(self.n)
    
    def log(self, msg):
        if self.debug:
            if self.logger is None:
                if self.cur_whale is None:
                    print(f"[WOA] [{self.itr}] {msg}")
                else:
                    print(f"[WOA] [{self.itr}] [WHALE {self.cur_whale + 1}] {msg}")
            else:
                if self.cur_whale is None:
                    self.logger(f"[{self.itr}] {msg}")
                else:
                    self.logger(f"[{self.itr}] [WHALE {self.cur_whale + 1}] {msg}")
    
    def _compute_A(self, a: float):
        r = np.random.uniform(0.0, 1.0, size=1)
        return (2.0*np.multiply(a, r)) - a

    def _compute_C(self):
        return 2.0 * np.random.uniform(0.0, 1.0, size=1)
    
    def __to_sentence_text(self, sol):
        return " ".join([self.words[i] for i in sol])
    
    def __calculate_fitness(self, solution: np.ndarray) -> float:
        self.calcattempt += 1
        solt = tuple(solution)
        if solt in self.cache:
            self.calccached += 1
            return self.cache[solt]
        
        sentence = self.__to_sentence_text(solution)
        submission = pd.DataFrame({'id': [0], 'text': [sentence] })
        perplexities = scorer.get_perplexity(submission["text"].tolist()) # TODO use self to access the scorer
        # print(f"{perplexities[0]} || {sentence}")
        self.cache[solt] = perplexities[0]
        self.calcnotcached += 1
        return perplexities[0]

    def __caching_state(self):
        self.log(f"[CACHING] attempt: [{self.calcattempt}], "
                    f"cached: [{self.calccached}] ({self.calccached / self.calcattempt * 100}%), "
                    f"calculated: [{self.calcnotcached}] ({self.calcnotcached / self.calcattempt * 100}%)")
    
    def __encircling_prey(self, current_pos: np.ndarray, best_pos: np.ndarray, A: float, C: float) -> np.ndarray:
        D = abs(C * best_pos - current_pos)
        new_pos = best_pos - A * D
        return np.argsort(new_pos)
    
    def __search_for_prey(self, current_pos: np.ndarray, random_pos: np.ndarray, A: float, C: float) -> np.ndarray:
        D = abs(C * random_pos - current_pos)
        new_pos = random_pos - A * D
        return np.argsort(new_pos) 
    
    def __bubble_net_attack(self, current_pos: np.ndarray, best_pos: np.ndarray) -> np.ndarray:
        D = abs(best_pos - current_pos)
        b = 1
        l = random.uniform(-1, 1)
        new_pos = D * np.exp(l * b) * np.cos(2 * np.pi * l) + best_pos
        return np.argsort(new_pos)
    
    def __amend_position(self, position: np.ndarray) -> np.ndarray:
        """Ensure position is a valid permutation."""
        return np.argsort(position)
   
    def __local_search(self, solution: np.ndarray) -> Tuple[np.ndarray, float]:
        return self.TabuSearch.optimize(solution)
    
    def optimize(self) -> Tuple[np.ndarray, float, List[float], List[list]]:
        # Initialize population with local search improvement
        population = []
        fitness_values = []
        for w in range(self.n_whales):
            self.cur_whale = w
            solution = self.__create_initial_sols()
            self.log(f"sol {solution} --> to improve")
            improved_solution, improved_fitness = self.__local_search(solution)
            self.log(f"{improved_solution} | {improved_fitness}")
            population.append(improved_solution)
            fitness_values.append(improved_fitness)
        self.cur_whale=None
        # population = [np.array([8, 6, 9, 1, 2, 5, 3, 0, 4, 7]), np.array([8, 6, 2, 9, 5, 3, 7, 0, 1, 4]), np.array([8, 6, 2, 9, 1, 4, 5, 7, 3, 0])]
        # fitness_values = [531.0074131628102, 530.3983005966822, 561.4057235990515]

        self.log("------------------------------")
        self.log(f"[WHALES]")
        self.log(population)
        self.log(fitness_values)
        self.log("------------------------------")
        
        best_idx = np.argmin(fitness_values)
        best_pos = population[best_idx].copy()
        best_fitness = fitness_values[best_idx]
        
        self.itr = 1
        while self.itr <= self.max_iter:
            self.log(f"[START ITER] {best_pos} | {best_fitness}")
            for w in range(self.n_whales):
                self.cur_whale = w
                whale = population[w]
                self.log(f"{whale} | {fitness_values[w]}")
                a = 2 - self.itr * (2 / self.max_iter)
                A = self._compute_A(a)
                C = self._compute_C()
                p = random.random()
                self.log(f"a={a}, A={A}, C={C}, p={p}")

                if p < 0.5:
                    if abs(A) < 1:
                        new_pos = self.__encircling_prey(whale, best_pos, A, C)
                        self.log(f"[MOVE] encircling prey --> {new_pos}")
                    else:
                        rand_idx = random.randint(0, self.n_whales-1)
                        random_pos = population[rand_idx]
                        new_pos = self.__search_for_prey(whale, random_pos, A, C)
                        self.log(f"[MOVE] search for prey --> {new_pos}")
                else:
                    new_pos = self.__bubble_net_attack(whale, best_pos)
                    self.log(f"[MOVE] bubble net attack --> {new_pos}")
                
                # new_pos = self.__amend_position(new_pos)
                # self.log(f"amend position --> {new_pos}")
                # Apply local search to improve the new position
                improved_pos, improved_fitness = self.__local_search(new_pos)
                self.log(f"[IMPROVE POSITION] {new_pos}, [{improved_fitness}]")
                
                population[w] = improved_pos
                fitness_values[w] = improved_fitness
                
                if improved_fitness < best_fitness:
                    best_pos = improved_pos.copy()
                    best_fitness = improved_fitness
                    self.log(f"[BEST] {best_pos}, [{best_fitness}]")
            self.cur_whale=None
            self.itr += 1

        self.__caching_state()
        return best_pos, best_fitness, self.__to_sentence_text(best_pos)

# %%
# # text = problem['text'][0]

# text = 'advent chimney elf family fireplace gingerbread mistletoe ornament reindeer scrooge'

# woa = WhaleOptimization(
#     text, score, 
#     n_whales=3, max_iter=1, debug=True, 
#     tabu_tenure=5, tabu_no_imp=1, tabu_max_iter=3
# )
# woa.optimize()

# %%
import pandas as pd
problem = pd.read_csv("/kaggle/input/santa-2024/sample_submission.csv")

res = []

for idx, row in problem.iterrows():
    print("----------------------------------------------")
    print("----------------------------------------------")
    print("----------------------------------------------")
    def logger(msg):
        print(f"[WOA {idx}] {msg}")
    woa = WhaleOptimization(
        row.text, score,
        n_whales=3, max_iter=10, debug=True, 
        tabu_tenure=10, tabu_no_imp=3, tabu_max_iter=20,
        logger = logger
    )
    sol, p, sen = woa.optimize()
    res.append({
        "id": len(res),
        "or": row.text,
        "sol": sol,
        "text": sen,
        "p": p
    })

submission_ = pd.DataFrame(res)
submission_
# Out:
# ----------------------------------------------
# ----------------------------------------------
# ----------------------------------------------
# [WOA 0] [None] [WHALE 1] sol [0 5 4 6 2 3 9 8 1 7] --> to improve
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] start [0 5 4 6 2 3 9 8 1 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 4810.95576331565
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [1679.8564191837218] [5 0 4 6 2 3 9 8 1 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1679.8564191837218]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1679.8564191837218
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [1019.2979575497574] [5 0 4 1 2 3 9 8 6 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [1019.2979575497574]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 1019.2979575497574
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [923.6470701622601] [5 3 4 1 2 0 9 8 6 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [923.6470701622601]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 923.6470701622601
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [923.6470701622601] [5 3 4 1 2 0 9 8 6 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 923.6470701622601
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [923.6470701622601] [5 3 4 1 2 0 9 8 6 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 923.6470701622601
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [923.6470701622601] [5 3 4 1 2 0 9 8 6 7]
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [None] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [5 3 4 1 2 0 9 8 6 7] | 923.6470701622601
# [WOA 0] [None] [WHALE 1] [5 3 4 1 2 0 9 8 6 7] | 923.6470701622601
# [WOA 0] [None] [WHALE 2] sol [7 2 9 1 6 8 5 4 3 0] --> to improve
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] start [7 2 9 1 6 8 5 4 3 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 1875.4491394800248
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [1437.3973359536405] [5 2 9 1 6 8 7 4 3 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1437.3973359536405]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1437.3973359536405
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [890.6700705335805] [8 2 9 1 6 5 7 4 3 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [890.6700705335805]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 890.6700705335805
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [582.39858954001] [8 6 9 1 2 5 7 4 3 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [582.39858954001]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 582.39858954001
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [539.9670924448286] [8 6 9 1 2 5 3 4 7 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [539.9670924448286]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 539.9670924448286
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [539.9670924448286] [8 6 9 1 2 5 3 4 7 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 539.9670924448286
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [539.9670924448286] [8 6 9 1 2 5 3 4 7 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 539.9670924448286
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [539.9670924448286] [8 6 9 1 2 5 3 4 7 0]
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [None] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 9 1 2 5 3 4 7 0] | 539.9670924448286
# [WOA 0] [None] [WHALE 2] [8 6 9 1 2 5 3 4 7 0] | 539.9670924448286
# [WOA 0] [None] [WHALE 3] sol [7 9 4 0 6 1 2 8 3 5] --> to improve
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] start [7 9 4 0 6 1 2 8 3 5]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 2254.2894772529253
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [1472.883301260079] [7 9 6 0 4 1 2 8 3 5]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [1472.883301260079]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 1472.883301260079
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [1133.0723781717336] [5 9 6 0 4 1 2 8 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [1133.0723781717336]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 1133.0723781717336
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [882.9562075037118] [8 9 6 0 4 1 2 5 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [882.9562075037118]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 882.9562075037118
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [684.6193245385164] [8 6 9 0 4 1 2 5 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [684.6193245385164]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 684.6193245385164
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [629.5996209167121] [8 6 9 5 4 1 2 0 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [5/20] [629.5996209167121]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 629.5996209167121
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [548.0452522105028] [8 6 9 5 2 1 4 0 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [6/20] [548.0452522105028]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 548.0452522105028
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [530.2293812037502] [8 6 9 2 5 1 4 0 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [7/20] [530.2293812037502]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [8] --- 530.2293812037502
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [513.9240250112387] [8 6 2 9 5 1 4 0 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [8/20] [513.9240250112387]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [9] --- 513.9240250112387
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [513.9240250112387] [8 6 2 9 5 1 4 0 3 7]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [10] --- 513.9240250112387
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [IM] [10/20] [497.24771651708886]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [11] --- 497.24771651708886
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [12] --- 497.24771651708886
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [ITER] [13] --- 497.24771651708886
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [None] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [None] [WHALE 3] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [None] ------------------------------
# [WOA 0] [None] [WHALES]
# [WOA 0] [None] [array([5, 3, 4, 1, 2, 0, 9, 8, 6, 7]), array([8, 6, 9, 1, 2, 5, 3, 4, 7, 0]), array([8, 6, 2, 9, 5, 1, 4, 7, 3, 0])]
# [WOA 0] [None] [923.6470701622601, 539.9670924448286, 497.24771651708886]
# [WOA 0] [None] ------------------------------
# [WOA 0] [1] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [1] [WHALE 1] [5 3 4 1 2 0 9 8 6 7] | 923.6470701622601
# [WOA 0] [1] [WHALE 1] a=1.8, A=[1.06073301], C=[0.81317722], p=0.7378532076391644
# [WOA 0] [1] [WHALE 1] [MOVE] bubble net attack --> [9 6 3 8 2 5 4 1 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] start [9 6 3 8 2 5 4 1 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 1087.50258206
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [840.6606575836672] [8 6 3 9 2 5 4 1 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [840.6606575836672]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 840.6606575836672
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [696.58131873628] [8 6 3 9 2 5 1 4 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [696.58131873628]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 696.58131873628
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [586.7372152731087] [8 6 2 9 3 5 1 4 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [586.7372152731087]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 586.7372152731087
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [538.9019347476238] [8 6 2 5 3 9 1 4 0 7]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [IM] [4/20] [538.9019347476238]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 538.9019347476238
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [IM] [5/20] [505.0654642899257]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 505.0654642899257
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 505.0654642899257
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [ITER] [8] --- 505.0654642899257
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [1] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 2 5 3 9 1 4 7 0] | 505.0654642899257
# [WOA 0] [1] [WHALE 1] [IMPROVE POSITION] [9 6 3 8 2 5 4 1 0 7], [505.0654642899257]
# [WOA 0] [1] [WHALE 2] [8 6 9 1 2 5 3 4 7 0] | 539.9670924448286
# [WOA 0] [1] [WHALE 2] a=1.8, A=[0.20482584], C=[0.82995126], p=0.6882329879865093
# [WOA 0] [1] [WHALE 2] [MOVE] bubble net attack --> [2 5 9 8 4 6 3 7 1 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] start [2 5 9 8 4 6 3 7 1 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 7271.028707877158
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [1759.7970984006117] [5 2 9 8 4 6 3 7 1 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1759.7970984006117]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1759.7970984006117
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [1178.1779510626532] [8 2 9 5 4 6 3 7 1 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [1178.1779510626532]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 1178.1779510626532
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [780.9082076264834] [8 6 9 5 4 2 3 7 1 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [780.9082076264834]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 780.9082076264834
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [615.1610232175685] [8 6 9 5 1 2 3 7 4 0]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [615.1610232175685]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 615.1610232175685
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [552.8875041123517] [8 6 9 5 1 2 3 0 4 7]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [IM] [5/20] [552.8875041123517]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 552.8875041123517
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [552.8875041123517] [8 6 9 5 1 2 3 0 4 7]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 552.8875041123517
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [552.8875041123517] [8 6 9 5 1 2 3 0 4 7]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [ITER] [8] --- 552.8875041123517
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [552.8875041123517] [8 6 9 5 1 2 3 0 4 7]
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [1] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 9 5 1 2 3 0 4 7] | 552.8875041123517
# [WOA 0] [1] [WHALE 2] [IMPROVE POSITION] [2 5 9 8 4 6 3 7 1 0], [552.8875041123517]
# [WOA 0] [1] [WHALE 3] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [1] [WHALE 3] a=1.8, A=[1.34945205], C=[0.04753783], p=0.2704671308099895
# [WOA 0] [1] [WHALE 3] [MOVE] search for prey --> [3 0 7 1 4 6 8 2 5 9]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] start [3 0 7 1 4 6 8 2 5 9]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 9221.732792161029
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [2153.1145402658544] [7 0 3 1 4 6 8 2 5 9]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [2153.1145402658544]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 2153.1145402658544
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1655.8413915474353] [7 9 3 1 4 6 8 2 5 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [1655.8413915474353]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 1655.8413915474353
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1335.363767461941] [5 9 3 1 4 6 8 2 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [1335.363767461941]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 1335.363767461941
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1116.1740039885517] [5 9 3 1 4 2 8 6 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [1116.1740039885517]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 1116.1740039885517
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1068.8947964836468] [5 9 1 3 4 2 8 6 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [IM] [5/20] [1068.8947964836468]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 1068.8947964836468
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1068.8947964836468] [5 9 1 3 4 2 8 6 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 1068.8947964836468
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1068.8947964836468] [5 9 1 3 4 2 8 6 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [ITER] [8] --- 1068.8947964836468
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [1068.8947964836468] [5 9 1 3 4 2 8 6 7 0]
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [1] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [5 9 1 3 4 2 8 6 7 0] | 1068.8947964836468
# [WOA 0] [1] [WHALE 3] [IMPROVE POSITION] [3 0 7 1 4 6 8 2 5 9], [1068.8947964836468]
# [WOA 0] [2] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [2] [WHALE 1] [8 6 2 5 3 9 1 4 7 0] | 505.0654642899257
# [WOA 0] [2] [WHALE 1] a=1.6, A=[-0.82969638], C=[1.01711588], p=0.6803036090272033
# [WOA 0] [2] [WHALE 1] [MOVE] bubble net attack --> [9 2 1 0 4 6 8 7 5 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] start [9 2 1 0 4 6 8 7 5 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 3265.242294670822
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [1654.4783711495097] [8 2 1 0 4 6 9 7 5 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1654.4783711495097]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1654.4783711495097
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [1038.7621528790594] [8 6 1 0 4 2 9 7 5 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [1038.7621528790594]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 1038.7621528790594
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [840.0075125137471] [8 6 5 0 4 2 9 7 1 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [840.0075125137471]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 840.0075125137471
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [610.3324746090606] [8 6 5 1 4 2 9 7 0 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [4/20] [610.3324746090606]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 610.3324746090606
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [560.9465398163399] [8 6 9 1 4 2 5 7 0 3]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [5/20] [560.9465398163399]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 560.9465398163399
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [560.1553570447046] [8 6 9 1 4 2 5 7 3 0]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [IM] [6/20] [560.1553570447046]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 560.1553570447046
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [560.1553570447046] [8 6 9 1 4 2 5 7 3 0]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [8] --- 560.1553570447046
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [560.1553570447046] [8 6 9 1 4 2 5 7 3 0]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [ITER] [9] --- 560.1553570447046
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [560.1553570447046] [8 6 9 1 4 2 5 7 3 0]
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [2] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 9 1 4 2 5 7 3 0] | 560.1553570447046
# [WOA 0] [2] [WHALE 1] [IMPROVE POSITION] [9 2 1 0 4 6 8 7 5 3], [560.1553570447046]
# [WOA 0] [2] [WHALE 2] [8 6 9 5 1 2 3 0 4 7] | 552.8875041123517
# [WOA 0] [2] [WHALE 2] a=1.6, A=[-0.92916593], C=[1.92508199], p=0.8699932578828845
# [WOA 0] [2] [WHALE 2] [MOVE] bubble net attack --> [9 2 7 4 5 8 6 3 1 0]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] start [9 2 7 4 5 8 6 3 1 0]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 4371.3942849059285
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [2204.2172728943383] [5 2 7 4 9 8 6 3 1 0]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [2204.2172728943383]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 2204.2172728943383
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [1302.844339877929] [5 2 7 0 9 8 6 3 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [1302.844339877929]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 1302.844339877929
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [1186.1729511947988] [5 2 3 0 9 8 6 7 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [1186.1729511947988]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 1186.1729511947988
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [1044.3903158203768] [8 2 3 0 9 5 6 7 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [1044.3903158203768]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 1044.3903158203768
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [719.1875261736598] [8 6 3 0 9 5 2 7 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [5/20] [719.1875261736598]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 719.1875261736598
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [627.6733823803945] [8 6 2 0 9 5 3 7 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [6/20] [627.6733823803945]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 627.6733823803945
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [597.4454616187938] [8 6 2 0 9 5 7 3 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [7/20] [597.4454616187938]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [8] --- 597.4454616187938
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [576.1670458366647] [8 6 2 3 9 5 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [8/20] [576.1670458366647]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [9] --- 576.1670458366647
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [570.6126920744904] [8 6 2 9 3 5 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [9/20] [570.6126920744904]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [10] --- 570.6126920744904
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [530.3983005966822] [8 6 2 9 5 3 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [IM] [10/20] [530.3983005966822]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [11] --- 530.3983005966822
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [530.3983005966822] [8 6 2 9 5 3 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [12] --- 530.3983005966822
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [530.3983005966822] [8 6 2 9 5 3 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [ITER] [13] --- 530.3983005966822
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [530.3983005966822] [8 6 2 9 5 3 7 0 1 4]
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [2] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 3 7 0 1 4] | 530.3983005966822
# [WOA 0] [2] [WHALE 2] [IMPROVE POSITION] [9 2 7 4 5 8 6 3 1 0], [530.3983005966822]
# [WOA 0] [2] [WHALE 3] [5 9 1 3 4 2 8 6 7 0] | 1068.8947964836468
# [WOA 0] [2] [WHALE 3] a=1.6, A=[0.69600365], C=[1.06815136], p=0.9489063793670695
# [WOA 0] [2] [WHALE 3] [MOVE] bubble net attack --> [9 5 2 4 7 8 6 1 0 3]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] start [9 5 2 4 7 8 6 1 0 3]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 5160.762243073844
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [2212.9255846828464] [8 5 2 4 7 9 6 1 0 3]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [2212.9255846828464]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 2212.9255846828464
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [1412.8733906526] [8 5 2 4 0 9 6 1 7 3]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [1412.8733906526]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 1412.8733906526
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [784.1990182794133] [8 6 2 4 0 9 5 1 7 3]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [784.1990182794133]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 784.1990182794133
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [625.9073197706339] [8 6 2 3 0 9 5 1 7 4]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [625.9073197706339]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 625.9073197706339
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [543.3845313786373] [8 6 2 3 0 9 5 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [5/20] [543.3845313786373]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 543.3845313786373
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [543.3845313786373] [8 6 2 3 0 9 5 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 543.3845313786373
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [509.90080827638036] [8 6 5 3 0 9 2 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [IM] [7/20] [509.90080827638036]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [8] --- 509.90080827638036
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [509.90080827638036] [8 6 5 3 0 9 2 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [9] --- 509.90080827638036
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [509.90080827638036] [8 6 5 3 0 9 2 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [ITER] [10] --- 509.90080827638036
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [509.90080827638036] [8 6 5 3 0 9 2 1 4 7]
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [2] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 5 3 0 9 2 1 4 7] | 509.90080827638036
# [WOA 0] [2] [WHALE 3] [IMPROVE POSITION] [9 5 2 4 7 8 6 1 0 3], [509.90080827638036]
# [WOA 0] [3] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [3] [WHALE 1] [8 6 9 1 4 2 5 7 3 0] | 560.1553570447046
# [WOA 0] [3] [WHALE 1] a=1.4, A=[0.91882228], C=[0.64646858], p=0.5033992777896944
# [WOA 0] [3] [WHALE 1] [MOVE] bubble net attack --> [2 3 5 9 6 8 4 1 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] start [2 3 5 9 6 8 4 1 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 5129.6088662222055
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [1209.906149051085] [5 3 2 9 6 8 4 1 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1209.906149051085]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1209.906149051085
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [966.4942471444222] [8 3 2 9 6 5 4 1 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [966.4942471444222]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 966.4942471444222
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [817.3209025466875] [8 3 2 9 6 5 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [817.3209025466875]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 817.3209025466875
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [559.5032046120716] [8 6 2 9 3 5 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [IM] [4/20] [559.5032046120716]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 559.5032046120716
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [IM] [5/20] [505.0654642899257]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 505.0654642899257
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 505.0654642899257
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [ITER] [8] --- 505.0654642899257
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [505.0654642899257] [8 6 2 5 3 9 1 4 7 0]
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [3] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 2 5 3 9 1 4 7 0] | 505.0654642899257
# [WOA 0] [3] [WHALE 1] [IMPROVE POSITION] [2 3 5 9 6 8 4 1 7 0], [505.0654642899257]
# [WOA 0] [3] [WHALE 2] [8 6 2 9 5 3 7 0 1 4] | 530.3983005966822
# [WOA 0] [3] [WHALE 2] a=1.4, A=[-0.19975275], C=[0.17987189], p=0.7165893083539687
# [WOA 0] [3] [WHALE 2] [MOVE] bubble net attack --> [9 7 5 6 8 2 4 1 0 3]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] start [9 7 5 6 8 2 4 1 0 3]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 2255.071086095948
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [1549.788629736855] [5 7 9 6 8 2 4 1 0 3]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1549.788629736855]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1549.788629736855
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [1091.146903151578] [5 3 9 6 8 2 4 1 0 7]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [1091.146903151578]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 1091.146903151578
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [953.944712777306] [5 3 9 6 8 2 1 4 0 7]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [953.944712777306]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 953.944712777306
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [858.3091520415084] [5 6 9 3 8 2 1 4 0 7]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [858.3091520415084]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 858.3091520415084
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [607.0564517828818] [8 6 9 3 5 2 1 4 0 7]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [5/20] [607.0564517828818]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 607.0564517828818
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [584.9708424882939] [8 6 9 3 5 2 1 4 7 0]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [6/20] [584.9708424882939]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 584.9708424882939
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [556.8296877508865] [8 6 5 3 9 2 1 4 7 0]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [IM] [7/20] [556.8296877508865]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [8] --- 556.8296877508865
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [556.8296877508865] [8 6 5 3 9 2 1 4 7 0]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [9] --- 556.8296877508865
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [556.8296877508865] [8 6 5 3 9 2 1 4 7 0]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [ITER] [10] --- 556.8296877508865
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [556.8296877508865] [8 6 5 3 9 2 1 4 7 0]
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [3] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 5 3 9 2 1 4 7 0] | 556.8296877508865
# [WOA 0] [3] [WHALE 2] [IMPROVE POSITION] [9 7 5 6 8 2 4 1 0 3], [556.8296877508865]
# [WOA 0] [3] [WHALE 3] [8 6 5 3 0 9 2 1 4 7] | 509.90080827638036
# [WOA 0] [3] [WHALE 3] a=1.4, A=[0.22108169], C=[0.77460361], p=0.19510091852336042
# [WOA 0] [3] [WHALE 3] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [619.2137848681151] [8 6 2 9 5 4 1 7 3 0]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [619.2137848681151]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 619.2137848681151
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [3] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [3] [WHALE 3] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [4] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [4] [WHALE 1] [8 6 2 5 3 9 1 4 7 0] | 505.0654642899257
# [WOA 0] [4] [WHALE 1] a=1.2, A=[0.90104381], C=[0.18333842], p=0.6341120064556356
# [WOA 0] [4] [WHALE 1] [MOVE] bubble net attack --> [9 2 1 4 6 0 8 7 5 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] start [9 2 1 4 6 0 8 7 5 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 2604.5023776750986
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [1184.7778434758743] [8 2 1 4 6 0 9 7 5 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1184.7778434758743]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1184.7778434758743
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [809.1604576810026] [8 6 1 4 2 0 9 7 5 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [809.1604576810026]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 809.1604576810026
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [734.3261287774029] [8 6 1 4 2 0 9 5 7 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [734.3261287774029]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 734.3261287774029
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [708.4482203412558] [8 6 4 1 2 0 9 5 7 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [4/20] [708.4482203412558]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 708.4482203412558
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [608.7060461207354] [8 6 9 1 2 0 4 5 7 3]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [5/20] [608.7060461207354]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 608.7060461207354
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [583.0846575514594] [8 6 9 1 2 0 3 5 7 4]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [6/20] [583.0846575514594]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 583.0846575514594
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [574.4881011293016] [8 6 9 1 2 5 3 0 7 4]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [7/20] [574.4881011293016]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [8] --- 574.4881011293016
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [531.0074131628102] [8 6 9 1 2 5 3 0 4 7]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [IM] [8/20] [531.0074131628102]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [9] --- 531.0074131628102
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [531.0074131628102] [8 6 9 1 2 5 3 0 4 7]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [10] --- 531.0074131628102
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [531.0074131628102] [8 6 9 1 2 5 3 0 4 7]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [ITER] [11] --- 531.0074131628102
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [531.0074131628102] [8 6 9 1 2 5 3 0 4 7]
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [4] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 9 1 2 5 3 0 4 7] | 531.0074131628102
# [WOA 0] [4] [WHALE 1] [IMPROVE POSITION] [9 2 1 4 6 0 8 7 5 3], [531.0074131628102]
# [WOA 0] [4] [WHALE 2] [8 6 5 3 9 2 1 4 7 0] | 556.8296877508865
# [WOA 0] [4] [WHALE 2] a=1.2, A=[0.15800031], C=[0.57581549], p=0.4937757911313513
# [WOA 0] [4] [WHALE 2] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [4] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [4] [WHALE 2] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [4] [WHALE 3] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [4] [WHALE 3] a=1.2, A=[0.28556804], C=[0.14312611], p=0.69205411142337
# [WOA 0] [4] [WHALE 3] [MOVE] bubble net attack --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [4] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [4] [WHALE 3] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [5] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 1] [8 6 9 1 2 5 3 0 4 7] | 531.0074131628102
# [WOA 0] [5] [WHALE 1] a=1.0, A=[-0.11557742], C=[1.4993258], p=0.44965405389905644
# [WOA 0] [5] [WHALE 1] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [5] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 1] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [5] [WHALE 2] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 2] a=1.0, A=[0.28690099], C=[0.99178371], p=0.2787221351137358
# [WOA 0] [5] [WHALE 2] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [5] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 2] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [5] [WHALE 3] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 3] a=1.0, A=[-0.9982471], C=[0.50217307], p=0.4422938121718727
# [WOA 0] [5] [WHALE 3] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [5] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [5] [WHALE 3] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [6] [START ITER] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 1] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 1] a=0.7999999999999998, A=[0.40988236], C=[1.33815437], p=0.9886945403067152
# [WOA 0] [6] [WHALE 1] [MOVE] bubble net attack --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [5] --- 503.80170626436353
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [IM] [5/20] [497.24771651708886]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [ITER] [8] --- 497.24771651708886
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [6] [WHALE 1] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 1] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [6] [WHALE 2] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 2] a=0.7999999999999998, A=[-0.2813125], C=[0.21506796], p=0.3320421561916578
# [WOA 0] [6] [WHALE 2] [MOVE] encircling prey --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [626.9509937472582] [8 6 2 9 5 4 1 7 0 3]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [IM] [2/20] [626.9509937472582]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [3] --- 626.9509937472582
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [IM] [3/20] [503.80170626436353]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [4] --- 503.80170626436353
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [IM] [4/20] [497.24771651708886]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [5] --- 497.24771651708886
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [6] --- 497.24771651708886
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [6] [WHALE 2] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 2] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# [WOA 0] [6] [WHALE 3] [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 3] a=0.7999999999999998, A=[-0.33276334], C=[1.3062877], p=0.8754096452280309
# [WOA 0] [6] [WHALE 3] [MOVE] bubble net attack --> [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] start [9 5 2 8 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 2626.3144485271314
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [1228.784192955151] [8 5 2 9 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [1228.784192955151]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 1228.784192955151
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [832.914306265911] [8 2 5 9 6 4 1 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [832.914306265911]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 832.914306265911
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [702.8995037814511] [8 6 5 9 2 4 1 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [702.8995037814511]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 702.8995037814511
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [573.5167199090753] [8 6 5 9 2 1 4 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [573.5167199090753]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 573.5167199090753
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [503.80170626436353] [8 6 2 9 5 1 4 7 0 3]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [5/20] [503.80170626436353]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 503.80170626436353
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [IM] [6/20] [497.24771651708886]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 497.24771651708886
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [NO IM] __1__
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [8] --- 497.24771651708886
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [NO IM] __2__
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [ITER] [9] --- 497.24771651708886
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [497.24771651708886] [8 6 2 9 5 1 4 7 3 0]
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [NO IM] __3__
# [WOA 0] [6] [WHALE 3] [LOCAL SEARCH] [NO IM] break; [8 6 2 9 5 1 4 7 3 0] | 497.24771651708886
# [WOA 0] [6] [WHALE 3] [IMPROVE POSITION] [9 5 2 8 6 4 1 7 0 3], [497.24771651708886]
# ...
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [15/20] [456.31429700755143]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [ITER] [16] --- 456.31429700755143
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [429.38812937629876] [36 88 32 54 92 57 44 50 46 15 60 56 63 93 55 23 12 97 83  5  1 43  2 11
#   9 42 45 52 24 18  7 74 35 75 61 85 29 90 58 16 33  6 10 98 66 96  8 20
#  48 30 68 69 47 21 64  4 37 22 71  0 27 94 53 59 72  3 81 87 73 84 26 67
#  40 41 31 76 70 91 25 38 28 86 77 51 78 49 65 95 62 99 82 39 80 79 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [16/20] [429.38812937629876]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [ITER] [17] --- 429.38812937629876
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [418.7700842480658] [36 88 32 54 92 57 44 50 46 15 94 56 63 93 55 23 12 97 83  5  1 43  2 11
#   9 42 45 52 24 18  7 74 35 75 61 85 29 90 58 16 33  6 10 98 66 96  8 20
#  48 30 68 69 47 21 64  4 37 22 71  0 27 60 53 59 72  3 81 87 73 84 26 67
#  40 41 31 76 70 91 25 38 28 86 77 51 78 49 65 95 62 99 82 39 80 79 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [17/20] [418.7700842480658]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [ITER] [18] --- 418.7700842480658
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [404.84673679176336] [36 88 32 54 92 57 44 50 46 15 94 56 63 93 55 23 12 97 83  5  1 43  2 37
#   9 42 45 52 24 18  7 74 35 75 61 85 29 90 58 16 33  6 10 98 66 96  8 20
#  48 30 68 69 47 21 64  4 11 22 71  0 27 60 53 59 72  3 81 87 73 84 26 67
#  40 41 31 76 70 91 25 38 28 86 77 51 78 49 65 95 62 99 82 39 80 79 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [18/20] [404.84673679176336]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [ITER] [19] --- 404.84673679176336
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [394.3724926718282] [36 88 32 54 92 57 44 50 46 15 94 56 63 93 55 23 12 97 83  5  1 43  2 37
#   9 42 45 52 24 18  7 74 35 75 61 85 29 90 58 16 33  6 10 98 66 96  8 20
#  48 30 68 69 47 21 64  4 11 22 71  0 27 60 53 59 72  3 81 87 73 84 26 67
#  40 41 31 76 70 91 25 38 28 86 77 51 78 49 65 95 99 62 82 39 80 79 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [19/20] [394.3724926718282]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [ITER] [20] --- 394.3724926718282
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [384.4448502868815] [36 88 32 54 92 57 44 50 46 15 94 56 63 93 55 23 12 97 83  5  1 43  2 37
#   9 42 45 52 24 18  7 74 35 75 61 85 29 90 58 16 33  6 10 98 66 96  8 20
#  48 30 60 69 47 21 64  4 11 22 71  0 27 68 53 59 72  3 81 87 73 84 26 67
#  40 41 31 76 70 91 25 38 28 86 77 51 78 49 65 95 99 62 82 39 80 79 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 2] [LOCAL SEARCH] [IM] [20/20] [384.4448502868815]
# [WOA 5] [10] [WHALE 2] [IMPROVE POSITION] [36 52 32 81 92  7 44 88 46 15 22 51 63 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 93 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 59 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34], [384.4448502868815]
# [WOA 5] [10] [WHALE 3] [ 8 16 54 92 49 57 88 11 46 56 55 15  6 66 87 33 83  5 79 43 97  1 42 45
#  53 93 50 28 86 40 24 74 35 95 75 61 90 69 51 12 58  7 98 23 10 20 96 36
#  48 47 85  4 30 13 21 71 72 94  0 27 37 68 59 81  2 67 22  3 73 26 64 89
#  84 63 91 76 70 41 25 44 38  9 32 29 65 18 80 60 78 77 62 17 99 82 14 52
#  39 31 34 19] | 375.230424379698
# [WOA 5] [10] [WHALE 3] a=0.0, A=[0.], C=[1.91482739], p=0.23853655568130505
# [WOA 5] [10] [WHALE 3] [MOVE] encircling prey --> [36 52 32 81 92  7 44 88 46 15 22 51 63 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 93 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 59 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] start [36 52 32 81 92  7 44 88 46 15 22 51 63 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 93 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 59 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [1] --- 839.3568760804022
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [774.6977651734665] [36 52 59 81 92  7 44 88 46 15 22 51 63 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 93 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 32 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [1/20] [774.6977651734665]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [2] --- 774.6977651734665
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [728.3878475391294] [36 52 59 81 92  7 44 88 46 15 22 51 93 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 63 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 32 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [2/20] [728.3878475391294]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [3] --- 728.3878475391294
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [699.8677575311506] [36 52 59 81 92  7 44 88 46 15 22 51 93 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 85 47 21 72  4 37 39 71  0 27 68 54 32 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [3/20] [699.8677575311506]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [4] --- 699.8677575311506
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [661.043228766834] [36 52 59 81 92  7 44 88 46 15 22 51 93 66 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [4/20] [661.043228766834]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [5] --- 661.043228766834
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [623.0694881550315] [36 52 59 81 92  7 44 88 46 15 22 51 93 66 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 29 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [5/20] [623.0694881550315]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [6] --- 623.0694881550315
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [605.7503361214783] [36 29 59 81 92  7 44 88 46 15 22 51 93 66 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 52 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [6/20] [605.7503361214783]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [7] --- 605.7503361214783
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [584.6498754309391] [36 29 59 81 92  7 44 88 46 15 22 51 93 13 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 52 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 66
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [7/20] [584.6498754309391]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [8] --- 584.6498754309391
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [539.8517553490979] [36 29 59 81 92 95 44 88 46 15 22 51 93 13 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 52 90 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [8/20] [539.8517553490979]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [9] --- 539.8517553490979
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [510.6336710644349] [36 29 59 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 52 22 58 79 33 12 10 98 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [9/20] [510.6336710644349]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [10] --- 510.6336710644349
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [487.76472281541413] [36 29 59 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 69 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 98  9 86 77 56 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 34]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [10/20] [487.76472281541413]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [11] --- 487.76472281541413
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [472.9789770245494] [36 29 59 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5  1 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 98  9 86 77 56 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [11/20] [472.9789770245494]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [12] --- 472.9789770245494
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [448.72790520147475] [36 29 59 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5 86 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 98  9  1 77 56 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [12/20] [448.72790520147475]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [13] --- 448.72790520147475
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [436.6814939184357] [36 29 56 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5 86 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72  4 37 39 71  0 27 68 54 32 57  3 64 87 73 84 26 67
#  40 41 31 76 70 91 25 98  9  1 77 59 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [13/20] [436.6814939184357]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [14] --- 436.6814939184357
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [420.25757851736773] [36 29 56 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5 86 43 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 26 67
#  40 41 31 76 70 91 25 98  9  1 77 59 78 49 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [14/20] [420.25757851736773]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [15] --- 420.25757851736773
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [411.19881165315746] [36 29 56 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 26 67
#  40 41 31 76 70 91 25 98  9  1 77 59 78 43 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [15/20] [411.19881165315746]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [16] --- 411.19881165315746
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [403.4555337865838] [36 91 56 81 92 95 44 88 46 15 90 51 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 96  8 20
#  48 30 94 28 47 21 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 26 67
#  40 41 31 76 70 29 25 98  9  1 77 59 78 43 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [16/20] [403.4555337865838]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [17] --- 403.4555337865838
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [389.1643140459563] [36 91 56 81 92 95 44 88 46 15 90 96 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 51  8 20
#  48 30 94 28 47 21 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 26 67
#  40 41 31 76 70 29 25 98  9  1 77 59 78 43 65  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [17/20] [389.1643140459563]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [18] --- 389.1643140459563
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [383.15572737502777] [36 91 56 81 92 95 44 88 46 15 90 96 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 45 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 51  8 20
#  48 30 94 28 47 21 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 65 67
#  40 41 31 76 70 29 25 98  9  1 77 59 78 43 26  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [18/20] [383.15572737502777]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [19] --- 383.15572737502777
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [377.9493128689216] [36 91 56 81 92 95 44 88 46 15 90 96 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 21 50 24 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 51  8 20
#  48 30 94 28 47 45 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 65 67
#  40 41 31 76 70 29 25 98  9  1 77 59 78 43 26  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [19/20] [377.9493128689216]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [ITER] [20] --- 377.9493128689216
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [363.98072955252337] [36 91 56 81 92 95 44 88 46 15 90 96 93 13 55 23  6 97 83  5 86 49 53 11
#  85 42 21 50 40 18  2 74 35 75 61 34 52 22 58 79 33 12 10 38 63 51  8 20
#  48 30 94 28 47 45 72 73 37 39 71  0 27 68 54 32 57  3 64 87  4 84 65 67
#  24 41 31 76 70 29 25 98  9  1 77 59 78 43 26  7 62 99 82 60 80 16 89 66
#  14 17 19 69]
# [WOA 5] [10] [WHALE 3] [LOCAL SEARCH] [IM] [20/20] [363.98072955252337]
# [WOA 5] [10] [WHALE 3] [IMPROVE POSITION] [36 52 32 81 92  7 44 88 46 15 22 51 63 66 55 23  6 97 83  5  1 43 53 11
#  28 42 45 50 24 18 64 74 35 75 61 69 29 90 58 79 33 12 10 98 93 96  8 20
#  48 30 68 85 47 21 72  4 37 39 71  0 27 94 54 59 57  3  2 87 73 84 26 67
#  40 41 31 76 70 91 25 38  9 86 77 56 78 49 65 95 62 99 82 60 80 16 89 13
#  14 17 19 34], [363.98072955252337]
# [WOA 5] [11] [CACHING] attempt: [66033], cached: [1382] (2.092892947465661%), calculated: [64651] (97.90710705253434%)
#    id                                                 or  \
# 0   0  advent chimney elf family fireplace gingerbrea...
# 1   1  advent chimney elf family fireplace gingerbrea...
# 2   2  yuletide decorations gifts cheer holiday carol...
# 3   3  yuletide decorations gifts cheer holiday carol...
# 4   4  hohoho candle poinsettia snowglobe peppermint ...
# 5   5  advent chimney elf family fireplace gingerbrea...
#
#                                                  sol  \
# 0                     [8, 6, 2, 9, 5, 1, 4, 7, 3, 0]
# 1  [8, 6, 2, 9, 5, 7, 0, 1, 4, 3, 17, 16, 10, 13,...
# 2  [16, 0, 5, 4, 3, 15, 18, 19, 11, 10, 12, 2, 13...
# 3  [10, 23, 2, 29, 16, 12, 15, 18, 19, 8, 17, 9, ...
# 4  [47, 9, 31, 5, 6, 10, 35, 28, 41, 48, 46, 38, ...
# 5  [59, 20, 66, 65, 55, 19, 16, 5, 46, 80, 42, 23...
#
#                                                 text
# 0  reindeer mistletoe elf scrooge gingerbread chi...
# 1  reindeer mistletoe elf scrooge gingerbread orn...
# 2  jingle yuletide carol holiday cheer holly naug...
# 3  sleigh of gifts unwrap jingle workshop holly n...
# 4  from puzzle star eggnog fruitcake game the nig...
# 5  puzzle yuletide dream believe eggnog and sleep...

# %%
submission = submission_[['id', 'text']]
submission.to_csv("submission.csv")
submission
# Out:
#    id                                               text
# 0   0  reindeer mistletoe elf scrooge gingerbread chi...
# 1   1  reindeer mistletoe elf scrooge gingerbread orn...
# 2   2  jingle yuletide carol holiday cheer holly naug...
# 3   3  sleigh of gifts unwrap jingle workshop holly n...
# 4   4  from puzzle star eggnog fruitcake game the nig...
# 5   5  puzzle yuletide dream believe eggnog and sleep...
